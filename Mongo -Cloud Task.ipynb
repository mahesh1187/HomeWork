# %%
import pymongo
import pandas as pd

# %% [markdown]
# # Reading data from UCI Repository

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data',header = None)
col=['Sex','Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']

df.columns = col
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# # Establishing Connection from MongoDB Cloud through Python

# %%
# Please copy your Cloud Connection and use here . as of now below are my connection properties

client = pymongo.MongoClient("mongodb+srv://test1:test2@cluster0.psxaj.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test

# %% [markdown]
# # Creating Database and collection (table) on the cloud environment  and verify database name through list_database_names command

# %%
db = client["abalone"]

# %%
collection = db["abalonedata"]

# %%
client.list_database_names()
# Out:
# ['abalone', 'admin', 'local']

# %% [markdown]
# # Inserting Data from UCI Respository to MongoDB Collection(table)

# %%
# Converting data to insert in MongoDB collection
testdata=df.to_dict(orient ='records')
testdata
# Out:
# [{'Sex': 'M',
#   'Length': 0.455,
#   'Diameter': 0.365,
#   'Height': 0.095,
#   'Whole weight': 0.514,
#   'Shucked weight': 0.2245,
#   'Viscera weight': 0.10099999999999999,
#   'Shell weight': 0.15,
#   'Rings': 15},
#  {'Sex': 'M',
#   'Length': 0.35,
#   'Diameter': 0.265,
#   'Height': 0.09,
#   'Whole weight': 0.2255,
#   'Shucked weight': 0.0995,
#   'Viscera weight': 0.0485,
#   'Shell weight': 0.07,
#   'Rings': 7},
#  {'Sex': 'F',
#   'Length': 0.53,
#   'Diameter': 0.42,
#   'Height': 0.135,
#   'Whole weight': 0.677,
#   'Shucked weight': 0.2565,
#   'Viscera weight': 0.1415,
#   'Shell weight': 0.21,
#   'Rings': 9},
#  {'Sex': 'M',
#   'Length': 0.44,
#   'Diameter': 0.365,
#   'Height': 0.125,
#   'Whole weight': 0.516,
#   'Shucked weight': 0.2155,
#   'Viscera weight': 0.114,
#   'Shell weight': 0.155,
#   'Rings': 10},
#  {'Sex': 'I',
#   'Length': 0.33,
#   'Diameter': 0.255,
#   'Height': 0.08,
#   'Whole weight': 0.205,
#   'Shucked weight': 0.0895,
# ...

# %%
collection.insert_many(testdata)

# %%
client.list_database_names()
# Out:
# ['abalone', 'admin', 'local']

# %% [markdown]
# # Reading data from inserted Database using python and also verify the data

# %%
db = client["abalone"]
collection = db["abalonedata"]

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('60c8c9969a2fb48beaddf04c'),
#  'Sex': 'M',
#  'Length': 0.455,
#  'Diameter': 0.365,
#  'Height': 0.095,
#  'Whole weight': 0.514,
#  'Shucked weight': 0.2245,
#  'Viscera weight': 0.10099999999999999,
#  'Shell weight': 0.15,
#  'Rings': 15}

# %%
all_data = collection.find()

# %%
Clean_df = pd.DataFrame (list(all_data))

# %% [markdown]
# # Here we can save data in different format like(excel, csv,txt etc.)

# %%
Clean_df.head()
# Out:
#                         _id Sex  Length  Diameter  Height  Whole weight  \
# 0  60c8c9969a2fb48beaddf04c   M   0.455     0.365   0.095        0.5140
# 1  60c8c9969a2fb48beaddf04d   M   0.350     0.265   0.090        0.2255
# 2  60c8c9969a2fb48beaddf04e   F   0.530     0.420   0.135        0.6770
# 3  60c8c9969a2fb48beaddf04f   M   0.440     0.365   0.125        0.5160
# 4  60c8c9969a2fb48beaddf050   I   0.330     0.255   0.080        0.2050
#
#    Shucked weight  Viscera weight  Shell weight  Rings
# 0          0.2245          0.1010         0.150     15
# 1          0.0995          0.0485         0.070      7
# 2          0.2565          0.1415         0.210      9
# 3          0.2155          0.1140         0.155     10
# 4          0.0895          0.0395         0.055      7

# %%
Clean_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b7fee11f99af> in <module>
# ----> 1 Clean_df.shape
#
# NameError: name 'Clean_df' is not defined

# %%
all_data = collection.find()

# %%
for i in all_data:
    print(i.get('_id'))
# Out:
# 60c8c9969a2fb48beaddf04c
# 60c8c9969a2fb48beaddf04d
# 60c8c9969a2fb48beaddf04e
# 60c8c9969a2fb48beaddf04f
# 60c8c9969a2fb48beaddf050
# 60c8c9969a2fb48beaddf051
# 60c8c9969a2fb48beaddf052
# 60c8c9969a2fb48beaddf053
# 60c8c9969a2fb48beaddf054
# 60c8c9969a2fb48beaddf055
# 60c8c9969a2fb48beaddf056
# 60c8c9969a2fb48beaddf057
# 60c8c9969a2fb48beaddf058
# 60c8c9969a2fb48beaddf059
# 60c8c9969a2fb48beaddf05a
# 60c8c9969a2fb48beaddf05b
# 60c8c9969a2fb48beaddf05c
# 60c8c9969a2fb48beaddf05d
# 60c8c9969a2fb48beaddf05e
# 60c8c9969a2fb48beaddf05f
# 60c8c9969a2fb48beaddf060
# 60c8c9969a2fb48beaddf061
# 60c8c9969a2fb48beaddf062
# 60c8c9969a2fb48beaddf063
# 60c8c9969a2fb48beaddf064
# 60c8c9969a2fb48beaddf065
# 60c8c9969a2fb48beaddf066
# 60c8c9969a2fb48beaddf067
# 60c8c9969a2fb48beaddf068
# 60c8c9969a2fb48beaddf069
# 60c8c9969a2fb48beaddf06a
# 60c8c9969a2fb48beaddf06b
# 60c8c9969a2fb48beaddf06c
# 60c8c9969a2fb48beaddf06d
# 60c8c9969a2fb48beaddf06e
# 60c8c9969a2fb48beaddf06f
# 60c8c9969a2fb48beaddf070
# ...

# %%
 Clean_df.to_csv('abalone.csv',index=False)
